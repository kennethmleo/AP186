# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import skimage

# %%
img = cv2.imread('cell_edit.png')
img_gray = cv2.imread('cell_edit.png', 0)

# %%
##Applying gaussian blur
img_gray_blur = cv2.GaussianBlur(img_gray,(3,3),0)

# %%
plt.figure(figsize=[12,6])
plt.subplot(121)
plt.imshow(img_gray, cmap='gray')
plt.axis('off')

plt.subplot(122)
plt.imshow(img_gray_blur, cmap='gray')
plt.axis('off')
plt.show()
